# %%
import pandas as pd
from sqlalchemy import create_engine

#conexion a SQL server
engine = create_engine('mssql+pyodbc://Leo_PC\\SQLEXPRESS/superstore?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes')

with engine.connect() as conn:
    print('conexion exitosa')
# Out:
# conexion exitosa
# C:\Users\leoje\AppData\Local\Temp\ipykernel_19468\1254328275.py:7: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   with engine.connect() as conn:

# %%
# Cargar CSVs procesados
dim_cliente = pd.read_csv('../data/processed/dim_cliente.csv')
dim_producto = pd.read_csv('../data/processed/dim_producto.csv')
dim_ubicacion = pd.read_csv('../data/processed/dim_ubicacion.csv')
fact_ventas = pd.read_csv('../data/processed/fact_ventas.csv')

# Cargar a SQL Server
dim_cliente.to_sql('dim_cliente', engine, if_exists='replace', index=False)
dim_producto.to_sql('dim_producto', engine, if_exists='replace', index=False)
dim_ubicacion.to_sql('dim_ubicacion', engine, if_exists='replace', index=False)
fact_ventas.to_sql('fact_ventas', engine, if_exists='replace', index=False)

print("Datos cargados correctamente")
# Out:
# Datos cargados correctamente
